# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# header and add Agent
HEADERS= ({'User-Agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36", 'Accept-Language':"en-US, en;q=0.5"})

# %%
# define URL
URL = 'https://www.amazon.com/s?k=apple+iphone+16&crid=181X87IEUBRCM&sprefix=apple+iphone+16%2Caps%2C309&ref=nb_sb_noss_1'

# %%
# HTTP request
webpage= requests.get(URL, headers= HEADERS)

# %%
webpage
# Out:
# <Response [200]>

# %%
# soup object containing all data
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
# fetch links as list of tag objects
links= soup.find_all("a",attrs={'class': "a-link-normal s-line-clamp-2 s-link-style a-text-normal"})

# %%
links
# Out:
# [<a class="a-link-normal s-line-clamp-2 s-link-style a-text-normal" href="/JQAKP-I16-PROMAX-Smartphone-Fingerprint/dp/B0DLKY2TV7/ref=sr_1_1?crid=181X87IEUBRCM&amp;dib=eyJ2IjoiMSJ9.0WmxWk2x7hi4zLWMjaqCIBSan50CvYjAkes38QY6eWsXWKM-x1PzSnJsCpEVxTQ6Zb3_kXH76l9lOOvPCq1e3doUt9UP4dgp7AlA0zhsUrRM7j63BQ-EIB0if-jOHX_zo8Qc1L97t_VXZESKwWct3zqKhN9Cjcp0Y__njsB5TvUWnA8SURFI0-E6ChM0ONi0aco3MIGf3Ecna85KixMVq72HxiydEH3LBzLinrUOgnY.mRa1tX0xY75eB4oW0YRWKuvTsnEr4aX-vQWMT3qOsvY&amp;dib_tag=se&amp;keywords=apple+iphone+16&amp;qid=1743155493&amp;sprefix=apple+iphone+16%2Caps%2C309&amp;sr=8-1"><h2 aria-label="I16 PROMAX 5G Phone,Smartphone Unlocked Cell Phone 12GB+512GB/6.99“ HD Screen Display/68MP+108MP Camera/7000 mAh, Dual SIM Card/Face Unlock/Fingerprint Button Unlock-and take Photos (White)" class="a-size-medium a-spacing-none a-color-base a-text-normal"><span>I16 PROMAX 5G Phone,Smartphone Unlocked Cell Phone 12GB+512GB/6.99“ HD Screen Display/68MP+108MP Camera/7000 mAh, Dual SIM Card/Face Unlock/Finger
# ...

# %%
# store the links in empty list
link_list = []

# %%
# Loop for extracting links from tag objects
for link in links:
    link_list.append(link.get('href'))

# %%
# creating empty dictionary with values required such as Product_Title, Product_Price, Product_Rating, Product_Review
dictnry = {"Product_Title":[], "Product_Price":[], "Product_Rating":[], "Product_Review":[]}

# %%
# function for extracting product Title, Product Price, Product rating, Product reviews
# Function to extract Product Title
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):

    try:
        price = new_soup.find("span", attrs={"class" :"a-price a-text-price a-size-medium apexPriceToPay"}).find("span", attrs={"class" :"a-offscreen"}).string.strip()

    except AttributeError:

        try:
            # If there is some deal price
            price = new_soup.find("span", attrs={"class" :"a-price a-text-price a-size-base"}).find("span", attrs={"class" :"a-offscreen"}).string.strip()
        except:
            price = ""

    return price

# Function to extract Product Rating
def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'class':'a-size-base a-color-base'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'data-hook':'total-review-count'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count

# %%
# Loop for extracting product details from each link
for link in link_list:
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        dictnry['Product_Title'].append(get_title(new_soup))
        dictnry['Product_Price'].append(get_price(new_soup))
        dictnry['Product_Rating'].append(get_rating(new_soup))
        dictnry['Product_Review'].append(get_review_count(new_soup))

# %%
new_webpage
# Out:
# <Response [200]>

# %%
# creating dataframe from dictionary
amazon_df = pd.DataFrame.from_dict(dictnry)

# %%
# replacing null values with NAN
# amazon_df['Product_Title'].replace("", np.nan, inplace=True)

# %%
# dropping columns if title is empty
amazon_df=amazon_df.dropna(subset= ["Product_Title"])

# %%
# creating csv from dataframe
amazon_df.to_csv("Amazon_iphone16.csv", header=True, index=False)

# %%
# final output ie. csv file
amazon_df
# Out:
#                                         Product_Title Product_Price  \
# 0   I16 PROMAX 5G Phone,Smartphone Unlocked Cell P...
# 1   Google Pixel 8a - Unlocked Android Phone with ...
# 2   Samsung Galaxy S24 Ultra Cell Phone, 256GB AI ...
# 3   OnePlus Open, 16GB RAM+512GB, Dual-SIM, Emeral...
# 4   UMIDIGI G9 5G Cell Phone, Android 14 Unlocked ...
# 5   Apple iPhone 13 Pro, 1TB, Graphite - T-Mobile ...       $629.99
# 6   Apple iPhone 8 64GB Unlocked - Gold & iPhone 8...
# 7   OnePlus 12,12GB RAM+256GB,Dual-SIM,Unlocked An...
# 8   Apple iPhone SE (2nd Generation), 64GB, Red - ...       $104.99
# 9   Samsung Galaxy S24 Cell Phone, 128GB AI Smartp...
# 10  Apple iPhone 14 Pro, 256GB, Silver - Unlocked ...
# 11  Apple iPhone 14 Pro Max, 256GB, Deep Purple - ...       $639.95
# 12  Apple iPhone 14 Pro Max, 256GB, Gold - Unlocke...
# 13  Apple iPhone 14, 128GB, Purple - Unlocked (Ren...
# 14  Apple iPhone SE 16GB Unlocked, 2016 1st Gen, A...
# ...
